# %%
import json, os
from collections import defaultdict

# %%
# Test

border = {"minecraft:adventure/adventuring_time":20}

name = ""
blocks = ""
tellraw = ""

with open('datapack/data/bc_wb/function/reward/biomes/adventuring_time.mcfunction', "r") as f:
    content = f.read()
    lines = content.split("\n")
    name = lines[1].split(" ")[3]
    blocks = border[name]
    #print(name)
    #print(lines[4][11:])
    tellraw = json.loads(lines[4][11:])
    tellraw['text'] = f' +{blocks} Blocks'
    #print(json.dumps(jsontest))
    print(content + "\n")

with open('datapack/data/bc_wb/function/reward/biomes/adventuring_time.mcfunction', "w") as f:
    f.write(f"""worldborder add {blocks*2} {blocks}
scoreboard players add {name} wb 1
scoreboard players set is_wb_run wb 0
schedule function bc_wb:untask {blocks}
tellraw @a {json.dumps(tellraw)}""")
# Out:
# worldborder add 40 20
# scoreboard players add minecraft:adventure/adventuring_time wb 1
# scoreboard players set is_wb_run wb 0
# schedule function bc_wb:untask 20
# tellraw @a {"text": " +20 Blocks", "color": "#B2FFEE", "hoverEvent": {"action": "show_text", "contents": ["", {"translate": "Adventuring Time", "color": "dark_purple"}, {"text": "\n"}, {"translate": "Discover each type of surface biome in the Overworld", "color": "#C900C7"}, {"text": "\n\n"}, {"translate": "Biomes", "color": "gray", "italic": true}]}}

# %%
border = defaultdict(lambda:[])
tiers = {'task': 1, 'goal': 5, 'challenge': 20}

for root in ['minecraft', 'blazeandcave']:
    folder_path = f'bac/data/{root}/advancement'
    for tab in os.listdir(folder_path):
        tab_path = os.path.join(folder_path, tab)
        root = folder_path.split('/')[2]
        prefix = f'{root}:{tab}'
        for adv in os.listdir(tab_path):
            true_name = f'{prefix}/{adv[:-5]}'
            adv_path = os.path.join(tab_path, adv)
            #print(true_name)
            # Print next json to open
            #print(adv_path)
            try:
                with open(adv_path, 'r') as f:
                    # If this fails Cavinator left a json error (yay!)
                    # Just navigate to the most recent json file and fix
                    try:
                        data = json.load(f)
                        display_name = data['display']['title']['translate']
                        tier = data['display'].get('frame','task')
                        border[true_name] = tiers[tier]
                    except json.decoder.JSONDecodeError:
                        border[true_name] = tiers['task']
            except KeyError:
                display_name = "NOT AN ADVANCEMENT"

print(border)
print(border['blazeandcave:bacap/advancement_legend'])
# Out:
# defaultdict(<function <lambda> at 0x00000150C24F9B20>, {'minecraft:adventure/adventuring_time': 20, 'minecraft:adventure/arbalistic': 20, 'minecraft:adventure/avoid_vibration': 1, 'minecraft:adventure/blowback': 20, 'minecraft:adventure/brush_armadillo': 1, 'minecraft:adventure/bullseye': 20, 'minecraft:adventure/crafters_crafting_crafters': 5, 'minecraft:adventure/craft_decorated_pot_using_only_sherds': 5, 'minecraft:adventure/fall_from_world_height': 20, 'minecraft:adventure/hero_of_the_village': 5, 'minecraft:adventure/honey_block_slide': 1, 'minecraft:adventure/kill_all_mobs': 20, 'minecraft:adventure/kill_a_mob': 1, 'minecraft:adventure/kill_mob_near_sculk_catalyst': 1, 'minecraft:adventure/lighten_up': 1, 'minecraft:adventure/lightning_rod_with_villager_no_fire': 5, 'minecraft:adventure/minecraft_trials_edition': 1, 'minecraft:adventure/ol_betsy': 1, 'minecraft:adventure/overoverkill': 20, 'minecraft:adventure/play_jukebox_in_meadows': 5, 'minecraft:adventure/read_power_of_chiseled_bookshelf': 1, 'minecraft:adventure/revaulting': 5, 'minecraft:adventure/root': 1, 'minecraft:adventure/salvage_sherd': 1, 'minecraft:adventure/shoot_arrow': 1, 'minecraft:adventure/sleep_in_bed': 1, 'minecraft:adventure/sniper_duel': 20, 'minecraft:adventure/spyglass_at_dragon': 1, 'minecraft:adventure/spyglass_at_ghast': 1, 'minecraft:adventure/spyglass_at_parrot': 1, 'minecraft:adventure/summon_iron_golem': 5, 'minecraft:adventure/throw_trident': 1, 'minecraft:adventure/totem_of_undying': 5, 'minecraft:adventure/trade': 1, 'minecraft:adventure/trade_at_world_height': 5, 'minecraft:adventure/trim_with_all_exclusive_armor_patterns': 20, 'minecraft:adventure/trim_with_any_armor_pattern': 1, 'minecraft:adventure/two_birds_one_arrow': 20, 'minecraft:adventure/under_lock_and_key': 1, 'minecraft:adventure/very_very_frightening': 20, 'minecraft:adventure/voluntary_exile': 1, 'minecraft:adventure/walk_on_powder_snow_with_leather_boots': 1, 'minecraft:adventure/whos_the_pillager_now': 1, 'minecraft:adventure/who_needs_rockets': 1, 'minecraft:end/dragon_breath': 1, 'minecraft:end/dragon_egg': 5, 'minecraft:end/elytra': 5, 'minecraft:end/enter_end_gateway': 1, 'minecraft:end/find_end_city': 1, 'minecraft:end/kill_dragon': 5, 'minecraft:end/levitate': 20, 'minecraft:end/respawn_dragon': 5, 'minecraft:end/root': 1, 'minecraft:husbandry/allay_deliver_cake_to_note_block': 5, 'minecraft:husbandry/allay_deliver_item_to_player': 1, 'minecraft:husbandry/axolotl_in_a_bucket': 1, 'minecraft:husbandry/balanced_diet': 20, 'minecraft:husbandry/break_diamond_hoe': 20, 'minecraft:husbandry/bred_all_animals': 20, 'minecraft:husbandry/breed_an_animal': 1, 'minecraft:husbandry/complete_catalogue': 20, 'minecraft:husbandry/feed_snifflet': 1, 'minecraft:husbandry/fishy_business': 1, 'minecraft:husbandry/froglights': 5, 'minecraft:husbandry/kill_axolotl_target': 1, 'minecraft:husbandry/leash_all_frog_variants': 5, 'minecraft:husbandry/make_a_sign_glow': 1, 'minecraft:husbandry/obtain_sniffer_egg': 1, 'minecraft:husbandry/plant_any_sniffer_seed': 1, 'minecraft:husbandry/plant_seed': 1, 'minecraft:husbandry/remove_wolf_armor': 1, 'minecraft:husbandry/repair_wolf_armor': 1, 'minecraft:husbandry/ride_a_boat_with_a_goat': 1, 'minecraft:husbandry/root': 1, 'minecraft:husbandry/safely_harvest_honey': 1, 'minecraft:husbandry/silk_touch_nest': 5, 'minecraft:husbandry/tactical_fishing': 1, 'minecraft:husbandry/tadpole_in_a_bucket': 1, 'minecraft:husbandry/tame_an_animal': 1, 'minecraft:husbandry/wax_off': 1, 'minecraft:husbandry/wax_on': 1, 'minecraft:husbandry/whole_pack': 20, 'minecraft:nether/all_effects': 20, 'minecraft:nether/all_potions': 20, 'minecraft:nether/brew_potion': 1, 'minecraft:nether/charge_respawn_anchor': 5, 'minecraft:nether/create_beacon': 5, 'minecraft:nether/create_full_beacon': 20, 'minecraft:nether/distract_piglin': 1, 'minecraft:nether/explore_nether': 5, 'minecraft:nether/fast_travel': 20, 'minecraft:nether/find_bastion': 1, 'minecraft:nether/find_fortress ...
# 20

# %%
data_path = 'datapack/data/bc_wb/function/reward'

for tab in os.listdir(data_path):
    for func in os.listdir(os.path.join(data_path,tab)):
        name = ""
        blocks = ""
        tellraw = ""

        print(f"writing to {tab}/{func}")
        with open(os.path.join(data_path,tab,func), "r") as f:
            content = f.read()
            lines = content.split("\n")
            name = lines[1].split(" ")[3]
            blocks = border[name]
            try:
                tellraw = json.loads(lines[4][11:])
            except IndexError: # advancement legend
                tellraw = json.loads(lines[2][11:])

            if (blocks == 1):
                tellraw['text'] = f' +{blocks} Block'
            else: 
                tellraw['text'] = f' +{blocks} Blocks'
            
        with open(os.path.join(data_path,tab,func), "w") as f:
            f.write(f"""worldborder add {blocks*2} {blocks}
scoreboard players add {name} wb 1
scoreboard players set is_wb_run wb 0
schedule function bc_wb:untask {blocks}
tellraw @a {json.dumps(tellraw)}""")
# Out:
# writing to adventure/allayance.mcfunction
# writing to adventure/all_chained_up.mcfunction
# writing to adventure/and_make_it_double.mcfunction
# writing to adventure/awards_ceremony.mcfunction
# writing to adventure/a_chiptune_relic.mcfunction
# writing to adventure/a_complete_catalogue.mcfunction
# writing to adventure/a_suspicious_advancement.mcfunction
# writing to adventure/beethoven.mcfunction
# writing to adventure/birthday_song.mcfunction
# writing to adventure/blowback.mcfunction
# writing to adventure/body_guard.mcfunction
# writing to adventure/break_wind.mcfunction
# writing to adventure/breeze_suppressor.mcfunction
# writing to adventure/brushed_away.mcfunction
# writing to adventure/budget_vex.mcfunction
# writing to adventure/businessman.mcfunction
# writing to adventure/buy_low_sell_high.mcfunction
# writing to adventure/careful_restoration.mcfunction
# writing to adventure/chromatic_armory.mcfunction
# writing to adventure/coordinated_flair.mcfunction
# writing to adventure/core_keeper.mcfunction
# writing to adventure/crafting_a_new_look.mcfunction
# writing to adventure/crazy_cat_lady.mcfunction
# writing to adventure/deals_off.mcfunction
# writing to adventure/diagon_allay.mcfunction
# writing to adventure/disc_jockey.mcfunction
# writing to adventure/do_you_want_to_trade.mcfunction
# writing to adventure/dry_spell.mcfunction
# writing to adventure/evelyn_evergreen.mcfunction
# writing to adventure/feeling_ill.mcfunction
# writing to adventure/filthy_rich.mcfunction
# writing to adventure/filthy_stinkin_rich.mcfunction
# writing to adventure/florist.mcfunction
# writing to adventure/from_under_your_feet.mcfunction
# writing to adventure/genesis_of_the_end.mcfunction
# writing to adventure/ghostbuster.mcfunction
# writing to adventure/good_lookin_treasure.mcfunction
# writing to adventure/grave_robber.mcfunction
# writing to adventure/guardian_destroyer.mcfunction
# writing to adventure/happy_trails.mcfunction
# writing to adventure/hard_mode_activated.mcfunction
# writing to adventure/heres_johnny.mcfunction
# writing to adventure/hero_of_the_village.mcfunction
# writing to adventure/hey_you_two_should_kiss.mcfunction
# writing to adventure/house_of_psychos.mcfunction
# writing to adventure/if_only_cats_grew_into_kittens.mcfunction
# writing to adventure/im_not_lost_anymore.mcfunction
# writing to adventure/its_so_beast_like.mcfunction
# writing to adventure/ive_got_a_bad_feeling_about_this.mcfunction
# writing to adventure/i_am_ravager_hear_me_roar.mcfunction
# writing to adventure/i_hereby_dub_thee.mcfunction
# writing to adventure/i_just_want_to_make_toast.mcfunction
# writing to adventure/jurassic_sniff.mcfunction
# writing to adventure/justice.mcfunction
# writing to adventure/keys_to_success.mcfunction
# writing to adventure/knowledge_is_power.mcfunction
# writing to adventure/laser_sharks.mcfunction
# writing to adventure/life_uhh_finds_a_way.mcfunction
# writing to adventure/lilypad_hatter.mcfunction
# writing to adventure/little_sniffs.mcfunction
# writing to adventure/mapmaker.mcfunction
# writing to adventure/mapmakers_table.mcfunction
# writing to adventure/map_room.mcfunction
# writing to adventure/master_trader.mcfunction
# writing to adventure/minecraft_trials_edition.mcfunction
# writing to adventure/mold_maker.mcfunction
# writing to adventure/monumental.mcfunction
# writing to adventure/murderer.mcfunction
# writing to adventure/music_to_my_ears.mcfunction
# writing to adventure/nerds_never_die.mcfunction
# writing to adventure/now_youre_thinking_with_portals.mcfunction
# writing to adventure/nyan_sheep.mcfunction
# writing to adventure/oh_look_it_dings.mcfunction
# writing to adventure/omniscient.mcfunction
# writing to adventure/out_of_posts.mcfunction
# writing to adventure/overpowered.mcfunction
# writing to adventure/picador.mcfunction
# writing to adventure/planting_the_past.mcfunction
# writing to adventure/postmortal.mcfunction
# writing to adventure/pottery_exhibition.mcfunction
# writing to adventure/prime_specimen.mcfunction
# writing to adventure/professional.mcfunction
# writing to adventure/raiders_of_the_lost_trim.mcfunction
# writing to adventure/raidin_master.mcfunction
# writing to adventure/rare_candy_shop.mcfunction
# writing to adventure/rebuilding_the_oceans.mcfunction
# writing to adventure/redemption_arc.mcfunction
# writing to adventure/rekt.mcfunction
# writing to adventure/respecting_the_remnants.mcfunction
# writing to adventure/retro_future_knight.mcfunction
# writing to adventure/revaulting.mcfunction
# writing to adventure/riot_shield.mcfunction
# writing to adventure/root.mcfunction
# writing to adventure/secret_of_the_igloo.mcfunction
# writing to adventure/shady_deals.mcfunction
# writing to adventure/slenderman.mcfunction
# writing to adventure/smithing_with_style.mcfunction
# writing to adventure/sound_the_alarm.mcfunction
# writing to adventure/spear_fishing.mcfunction
# writing to adventure/sponge_miner.mcfunction
# writing to adventure/stacked_smither.mcfunction
# writing to adventure/star_trader.mcfunction
# writing to adventure/superhero_of_the_village.mcfunction
# writing to adventure/sus.mcfunction
# writing to adventure/the_deep_end.mcfunction
# writing to adventure/the_one_and_true_johnny.mcfunction
# writing to adventure/the_shielding.mcfunction
# writing to adventure/the_sound_of_music.mcfunction
# writing to adventure/the_sound_of_silence.mcfunction
# writing to adventure/the_tribal_villagers.mcfunction
# writing to adventure/this_will_be_a_breeze.mcfunction
# writing to adventure/tomb_raider.mcfunction
# writing to adventure/town_planner.mcfunction
# writing to adventure/traveller.mcfunction
# writing to adventure/travelling_merchant.mcfunction
# writing to adventure/treasure_map.mcfunction
# writing to adventure/tricky_treasures.mcfunction
# writing to adventure/truffle_worm.mcfunction
# writing to adventure/under_lock_and_key.mcfunction
# writing to adventure/undying_fandom.mcfunction
# writing to adventure/vault_hunter.mcfunction
# writing to adventure/veteran_of_the_village.mcfunction
# writing to adventure/vexingly_hard_to_find.mcfunction
# writing to adventure/village_settler.mcfunction
# writing to adventure/war_is_coming.mcfunction
# writing to adventure/were_being_attacked.mcfunction
# writing to adventure/whats_up_doc.mcfunction
# writing to adventure/what_a_deal.mcfunction
# writing to adventure/who_needs_rockets.mcfunction
# writing to adventure/witchcraft.mcfunction
# writing to adventure/wololo.mcfunction
# writing to adventure/workaholic.mcfunction
# writing to adventure/your_daily_fix.mcfunction
# writing to adventure/youve_got_a_friend_in_me.mcfunction
# writing to adventure/you_are_the_pillager.mcfunction
# writing to animal/animal_kingdom.mcfunction
# writing to animal/aquarium.mcfunction
# writing to animal/are_we_there_yet.mcfunction
# writing to animal/armadoggo.mcfunction
# writing to animal/artificial_selection.mcfunction
# writing to animal/axeolotl.mcfunction
# writing to animal/axolittle.mcfunction
# writing to animal/axolotl_of_them.mcfunction
# writing to animal/a_horse_in_shining_armor.mcfunction
# writing to animal/bacon.mcfunction
# writing to animal/battle_of_the_bands.mcfunction
# writing to animal/beeloons.mcfunction
# writing to animal/bee_our_guest.mcfunction
# writing to animal/billy_the_kid.mcfunction
# writing to animal/birdkeeper.mcfunction
# writing to animal/blackberry_market.mcfunction
# writing to animal/blistering_barnacles.mcfunction
# writing to animal/bukkit_bukkit.mcfunction
# writing to animal/bunny_lover.mcfunction
# writing to animal/caprymphony.mcfunction
# writing to animal/catching_nemo.mcfunction
# writing to animal/cephalight.mcfunction
# writing to animal/chatterbox.mcfunction
# writing to animal/chicken_cooper.mcfunction
# writing to animal/colorful_cavalry.mcfunction
# writing to animal/cool_kids.mcfunction
# writing to animal/cowboy.mcfunction
# writing to animal/cow_tipper.mcfunction
# writing to animal/delicious_fish.mcfunction
# writing to animal/desert_rider.mcfunction
# writing to animal/direct_fishing.mcfunction
# writing to animal/farmadillo.mcfunction
# writing to animal/fashion_statement.mcfunction
# writing to animal/feeding_the_chickens.mcfunction
# writing to animal/feeling_sheepish.mcfunction
# writing to animal/fishy_business.mcfunction
# writing to animal/flashy_items.mcfunction
# writing to animal/foal_play.mcfunction
# writing to animal/follow_the_leader.mcfunction
# writing to animal/foxy_thievery.mcfunction
# writing to animal/fractal.mcfunction
# writing to animal/frog_family.mcfunction
# writing to animal/fuzzy_feet.mcfunction
# writing to animal/getting_into_a_stew.mcfunction
# writing to animal/glow_and_behold.mcfunction
# writing to animal/goat_out_of_here.mcfunction
# writing to animal/goat_simulator.mcfunction
# writing to animal/going_down_the_rabbit_hole.mcfunction
# writing to animal/good_as_new.mcfunction
# writing to animal/grinding_nemo.mcfunction
# writing to animal/have_a_shearful_day.mcfunction
# writing to animal/heavy_duty_caravan.mcfunction
# writing to animal/hey_look_mom.mcfunction
# writing to animal/high_steaks.mcfunction
# writing to animal/hive_mind.mcfunction
# writing to animal/honey_im_home.mcfunction
# writing to animal/horse_armorer.mcfunction
# writing to animal/humble_bundle.mcfunction
# writing to animal/hump_day.mcfunction
# writing to animal/iceologer_shouldve_won.mcfunction
# writing to animal/in_a_hole_there_lived_a_rabbit.mcfunction
# writing to animal/isnt_it_scute.mcfunction
# writing to animal/is_it_a_bird.mcfunction
# writing to animal/its_high_noon.mcfunction
# writing to animal/just_keeps_going.mcfunction
# writing to animal/leader_of_the_pack.mcfunction
# writing to animal/lead_the_way.mcfunction
# writing to animal/live_and_let_dye.mcfunction
# writing to animal/llama_festival.mcfunction
# writing to animal/llama_llama_duck_king.mcfunction
# writing to animal/loud_and_proud.mcfunction
# writing to animal/lucky_charm.mcfunction
# writing to animal/mary_had_a_little_lamb.mcfunction
# writing to animal/master_angler.mcfunction
# writing to animal/master_farrier.mcfunction
# writing to animal/milkshroom.mcfunction
# writing to animal/milk_does_your_body_good.mcfunction
# writing to animal/mooshroom_kingdom.mcfunction
# writing to animal/mushroom_scientist.mcfunction
# writing to animal/nest_quick.mcfunction
# writing to animal/not_the_bees.mcfunction
# writing to animal/overpopulation.mcfunction
# writing to animal/paw_patrol.mcfunction
# writing to animal/pig_slaughterer.mcfunction
# writing to animal/poacher.mcfunction
# writing to animal/pork_chop.mcfunction
# writing to animal/puppies_yipe.mcfunction
# writing to animal/rabbit_season.mcfunction
# writing to animal/rainbow_collection.mcfunction
# writing to animal/ram.mcfunction
# writing to animal/repopulation.mcfunction
# writing to animal/root.mcfunction
# writing to animal/salmonella_poisoning.mcfunction
# writing to animal/save_the_turtles.mcfunction
# writing to animal/screaming_milk.mcfunction
# writing to animal/scuttler.mcfunction
# writing to animal/sheariously.mcfunction
# writing to animal/shear_brilliance.mcfunction
# writing to animal/shoe_shed.mcfunction
# writing to animal/silence_of_the_lambs.mcfunction
# writing to animal/snow_fox_64.mcfunction
# writing to animal/someones_been_here_before.mcfunction
# writing to animal/so_good.mcfunction
# writing to animal/so_hungry_i_could_eat_a_horse.mcfunction
# writing to animal/so_i_got_that_going_for_me.mcfunction
# writing to animal/stay_calmer.mcfunction
# writing to animal/sticky_situation.mcfunction
# writing to animal/super_mooshroom.mcfunction
# writing to animal/sushi.mcfunction
# writing to animal/swine_sailing.mcfunction
# writing to animal/tactical_fishing.mcfunction
# writing to animal/thanks_a_lotl.mcfunction
# writing to animal/theyre_breeding_like_rabbits.mcfunction
# writing to animal/the_cutest_predator.mcfunction
# writing to animal/the_healing_power_of_friendship.mcfunction
# writing to animal/the_high_road.mcfunction
# writing to animal/the_whole_pack.mcfunction
# writing to animal/tickle_time.mcfunction
# writing to animal/totally_not_an_afk_fisher.mcfunction
# writing to animal/total_beelocation.mcfunction
# writing to animal/treasure_hunter.mcfunction
# writing to animal/tropical_collection.mcfunction
# writing to animal/true_cow_tipper.mcfunction
# writing to animal/turtle_army.mcfunction
# writing to animal/turtle_soldier.mcfunction
# writing to animal/whatever_floats_your_goat.mcfunction
# writing to animal/what_a_piece_of_junk.mcfunction
# writing to animal/what_does_the_fox_say.mcfunction
# writing to animal/when_pigs_used_to_fly.mcfunction
# writing to animal/when_the_squad_hops_into_town.mcfunction
# writing to animal/wheres_the_honey_lebowski.mcfunction
# writing to animal/which_came_first.mcfunction
# writing to animal/winnie_the_pooh.mcfunction
# writing to animal/wooly.mcfunction
# writing to animal/ya_like_jazz.mcfunction
# writing to animal/you_lead_ill_follow.mcfunction
# writing to bacap/advancement_legend.mcfunction
# writing to bacap/adventure_milestone.mcfunction
# writing to bacap/animal_milestone.mcfunction
# writing to bacap/benchmarking.mcfunction
# writing to bacap/biomes_milestone.mcfunction
# writing to bacap/building_milestone.mcfunction
# writing to bacap/challenges_milestone.mcfunction
# writing to bacap/enchanting_milestone.mcfunction
# writing to bacap/end_milestone.mcfunction
# writing to bacap/farming_milestone.mcfunction
# writing to bacap/getting_wood.mcfunction
# writing to bacap/mining_milestone.mcfunction
# writing to bacap/monsters_milestone.mcfunction
# writing to bacap/nether_milestone.mcfunction
# writing to bacap/potion_milestone.mcfunction
# writing to bacap/redstone_milestone.mcfunction
# writing to bacap/statistics_milestone.mcfunction
# writing to bacap/time_to_chop.mcfunction
# writing to bacap/time_to_dig.mcfunction
# writing to bacap/time_to_farm.mcfunction
# writing to bacap/time_to_mine.mcfunction
# writing to bacap/time_to_strike.mcfunction
# writing to bacap/weaponry_milestone.mcfunction
# writing to biomes/adventuring_time.mcfunction
# writing to biomes/ahoy.mcfunction
# writing to biomes/atlantis.mcfunction
# writing to biomes/bamboom.mcfunction
# writing to biomes/barbearian.mcfunction
# writing to biomes/boatception.mcfunction
# writing to biomes/boaty_mcboatface.mcfunction
# writing to biomes/captain_america.mcfunction
# writing to biomes/cargo_carrier.mcfunction
# writing to biomes/cold_feet.mcfunction
# writing to biomes/construction_worker.mcfunction
# writing to biomes/dive_bomb.mcfunction
# writing to biomes/dolphin_dasher.mcfunction
# writing to biomes/echolocation.mcfunction
# writing to biomes/edge_of_the_jungle.mcfunction
# writing to biomes/enchanted_forest.mcfunction
# writing to biomes/everybody_loves_ice.mcfunction
# writing to biomes/flipper.mcfunction
# writing to biomes/flower_power.mcfunction
# writing to biomes/for_you_my_sweet.mcfunction
# writing to biomes/free_diver.mcfunction
# writing to biomes/high_feet.mcfunction
# writing to biomes/in_a_pickle.mcfunction
# writing to biomes/just_a_sample.mcfunction
# writing to biomes/just_keep_swimming.mcfunction
# writing to biomes/kilometre_walk.mcfunction
# writing to biomes/kung_fu_panda.mcfunction
# writing to biomes/light_as_a_rabbit.mcfunction
# writing to biomes/lion_hunter.mcfunction
# writing to biomes/moskstraumen.mcfunction
# writing to biomes/no_reefing.mcfunction
# writing to biomes/one_with_the_forest.mcfunction
# writing to biomes/overgrown.mcfunction
# writing to biomes/pandamonium.mcfunction
# writing to biomes/powder_full.mcfunction
# writing to biomes/pretty_in_pink.mcfunction
# writing to biomes/pushed_around.mcfunction
# writing to biomes/qinling.mcfunction
# writing to biomes/root.mcfunction
# writing to biomes/simba.mcfunction
# writing to biomes/sleep_with_the_fishes.mcfunction
# writing to biomes/smooth_operator.mcfunction
# writing to biomes/so_long_and_thanks_for_all_the_fish.mcfunction
# writing to biomes/spike_ice.mcfunction
# writing to biomes/tarzan.mcfunction
# writing to biomes/ten_thousand_blocks.mcfunction
# writing to biomes/theres_a_zombie_on_the_lawn.mcfunction
# writing to biomes/the_great_blocky_reef.mcfunction
# writing to biomes/the_mighty_jungle.mcfunction
# writing to biomes/the_sea_calls_you.mcfunction
# writing to biomes/thick_ice.mcfunction
# writing to biomes/thin_ice.mcfunction
# writing to biomes/this_snow_is_snowier.mcfunction
# writing to biomes/titanic.mcfunction
# writing to biomes/top_of_the_world.mcfunction
# writing to biomes/voyage.mcfunction
# writing to biomes/warm_feet.mcfunction
# writing to biomes/were_going_on_a_bear_hunt.mcfunction
# writing to biomes/wet_feet.mcfunction
# writing to biomes/x_marks_the_spot.mcfunction
# writing to biomes/zoologist.mcfunction
# writing to building/agent_smithing_table.mcfunction
# writing to building/ah_my_old_enemy.mcfunction
# writing to building/and_open.mcfunction
# writing to building/armor_display.mcfunction
# writing to building/art_gallery.mcfunction
# writing to building/a_good_start.mcfunction
# writing to building/a_masterpiece.mcfunction
# writing to building/bamboozled.mcfunction
# writing to building/barking_mad.mcfunction
# writing to building/barrel_rider.mcfunction
# writing to building/blackstonehenge.mcfunction
# writing to building/blast_it.mcfunction
# writing to building/bricks.mcfunction
# writing to building/bubble_bubble_toil_and_trouble.mcfunction
# writing to building/built_on_sand_set_in_stone.mcfunction
# writing to building/bulbous.mcfunction
# writing to building/camping_out.mcfunction
# writing to building/cerulean.mcfunction
# writing to building/change_of_sheets.mcfunction
# writing to building/cherry_bomb.mcfunction
# writing to building/classic_pocket_edition_block.mcfunction
# writing to building/classy_glassy.mcfunction
# writing to building/clay_dough.mcfunction
# writing to building/colors_of_the_wind.mcfunction
# writing to building/concrete_evidence.mcfunction
# writing to building/crazy_walls.mcfunction
# writing to building/creepers_and_withers.mcfunction
# writing to building/cut_in_half.mcfunction
# writing to building/deepslate_conspiracy.mcfunction
# writing to building/delicious_hot_schmoes.mcfunction
# writing to building/electric.mcfunction
# writing to building/elmer_mudd.mcfunction
# writing to building/en_garde.mcfunction
# writing to building/expensive.mcfunction
# writing to building/fake_fortress.mcfunction
# writing to building/fake_monument.mcfunction
# writing to building/fake_stronghold.mcfunction
# writing to building/festival_of_lights.mcfunction
# writing to building/fluorescent.mcfunction
# writing to building/fruit_of_the_looms.mcfunction
# writing to building/glowing.mcfunction
# writing to building/grass_type.mcfunction
# writing to building/greek_art_decor.mcfunction
# writing to building/halloween.mcfunction
# writing to building/hanging_around.mcfunction
# writing to building/happy_birthday.mcfunction
# writing to building/harry_potter.mcfunction
# writing to building/help_ive_been_framed.mcfunction
# writing to building/hot_tub.mcfunction
# writing to building/incandescent.mcfunction
# writing to building/insomniac.mcfunction
# writing to building/its_a_sign.mcfunction
# writing to building/its_a_trap.mcfunction
# writing to building/its_original_form.mcfunction
# writing to building/i_dont_like_sand.mcfunction
# writing to building/jailhouse_block.mcfunction
# writing to building/ladder_climbers_inc.mcfunction
# writing to building/let_there_be_light.mcfunction
# writing to building/lighten_up.mcfunction
# writing to building/living_dummy.mcfunction
# writing to building/lost_its_bark.mcfunction
# writing to building/mangrove_master.mcfunction
# writing to building/mannequin.mcfunction
# writing to building/master_logger.mcfunction
# writing to building/no_banner_only_color.mcfunction
# writing to building/no_chain_no_gain.mcfunction
# writing to building/one_pickle_two_pickle_sea_pickle_four.mcfunction
# writing to building/pane_in_the_glass.mcfunction
# writing to building/pathways.mcfunction
# writing to building/pot_planter.mcfunction
# writing to building/prepare_to_meet_your_loom.mcfunction
# writing to building/professor_birch.mcfunction
# writing to building/professor_dark_oak.mcfunction
# writing to building/professor_oak.mcfunction
# writing to building/rainbow_dreams.mcfunction
# writing to building/rainbow_sand.mcfunction
# writing to building/raise_the_flag.mcfunction
# writing to building/rock_collection.mcfunction
# writing to building/rock_polish.mcfunction
# writing to building/root.mcfunction
# writing to building/setting_up_the_mood.mcfunction
# writing to building/sharpening_station.mcfunction
# writing to building/shelf_expression.mcfunction
# writing to building/shroom_lightyear.mcfunction
# writing to building/sign_off.mcfunction
# writing to building/skyblock.mcfunction
# writing to building/slabs_for_days.mcfunction
# writing to building/smooth_dude.mcfunction
# writing to building/spawn_camping.mcfunction
# writing to building/spruce_lee.mcfunction
# writing to building/stairs_no.mcfunction
# writing to building/stationary_storage.mcfunction
# writing to building/stripper.mcfunction
# writing to building/stuck_in_the_mud.mcfunction
# writing to building/sweet_dreams.mcfunction
# writing to building/the_acacia_king.mcfunction
# writing to building/the_glazed_terracotta_army.mcfunction
# writing to building/the_jungler.mcfunction
# writing to building/the_rainbow_you_always_wanted.mcfunction
# writing to building/the_ritual_begins.mcfunction
# writing to building/the_terracotta_army.mcfunction
# writing to building/the_walls.mcfunction
# writing to building/torched.mcfunction
# writing to building/translucence.mcfunction
# writing to building/tuff_stuff.mcfunction
# writing to building/washing_machine.mcfunction
# writing to building/what_a_pane.mcfunction
# writing to building/writers_block.mcfunction
# writing to building/yay_i_got_my_wood.mcfunction
# writing to building/your_door_was_locked.mcfunction
# writing to challenges/abyss_lord.mcfunction
# writing to challenges/ad_astra.mcfunction
# writing to challenges/all_the_blocks.mcfunction
# writing to challenges/all_the_items.mcfunction
# writing to challenges/a_million_blocks_away.mcfunction
# writing to challenges/biological_warfare.mcfunction
# writing to challenges/constellation.mcfunction
# writing to challenges/creepergeddon.mcfunction
# writing to challenges/death_from_all.mcfunction
# writing to challenges/dragon_army.mcfunction
# writing to challenges/dragon_vs_dragon_ii_electric_boogaloo.mcfunction
# writing to challenges/dragon_vs_wither_the_pre_sequel.mcfunction
# writing to challenges/endergeddon.mcfunction
# writing to challenges/explorer_of_worlds.mcfunction
# writing to challenges/global_vaccination.mcfunction
# writing to challenges/hearts_of_the_stack.mcfunction
# writing to challenges/highway_to_hell.mcfunction
# writing to challenges/how_did_we_get_here.mcfunction
# writing to challenges/immortal.mcfunction
# writing to challenges/im_in_space.mcfunction
# writing to challenges/i_am_loot.mcfunction
# writing to challenges/nuclear_fusion.mcfunction
# writing to challenges/overwarden.mcfunction
# writing to challenges/poglin.mcfunction
# writing to challenges/potion_master.mcfunction
# writing to challenges/riddle_me_this.mcfunction
# writing to challenges/rise_of_the_skeletons.mcfunction
# writing to challenges/root.mcfunction
# writing to challenges/stack_all_the_blocks.mcfunction
# writing to challenges/stack_all_the_items.mcfunction
# writing to challenges/stockbroker.mcfunction
# writing to challenges/telescopic.mcfunction
# writing to challenges/the_devils_distance.mcfunction
# writing to challenges/the_perfect_run.mcfunction
# writing to challenges/the_world_is_ending.mcfunction
# writing to challenges/ultimate_enchanter.mcfunction
# writing to challenges/warlock.mcfunction
# writing to challenges/were_in_the_endgame_now.mcfunction
# writing to challenges/zombie_apocalypse.mcfunction
# writing to enchanting/arbalistic.mcfunction
# writing to enchanting/armor_for_the_masses.mcfunction
# writing to enchanting/a_rather_pointy_fence_post.mcfunction
# writing to enchanting/bane_of_one_shotting_spiders.mcfunction
# writing to enchanting/baron_of_blacksmiths.mcfunction
# writing to enchanting/boomerang.mcfunction
# writing to enchanting/bow_down_to_me.mcfunction
# writing to enchanting/complete_enchanter.mcfunction
# writing to enchanting/curses.mcfunction
# writing to enchanting/do_a_barrel_roll.mcfunction
# writing to enchanting/fiery.mcfunction
# writing to enchanting/fortunate_son.mcfunction
# writing to enchanting/god_of_thunder.mcfunction
# writing to enchanting/gotta_go_fast.mcfunction
# writing to enchanting/handmade_blinding.mcfunction
# writing to enchanting/heavy_metal.mcfunction
# writing to enchanting/ill_be_back.mcfunction
# writing to enchanting/knocking_your_socks_off.mcfunction
# writing to enchanting/let_it_go.mcfunction
# writing to enchanting/librarian.mcfunction
# writing to enchanting/like_a_cat.mcfunction
# writing to enchanting/like_a_ninja.mcfunction
# writing to enchanting/mace_windu.mcfunction
# writing to enchanting/machine_bow.mcfunction
# writing to enchanting/magical_stockpile.mcfunction
# writing to enchanting/master_arbalist.mcfunction
# writing to enchanting/master_armorer.mcfunction
# writing to enchanting/master_axeman.mcfunction
# writing to enchanting/master_digger.mcfunction
# writing to enchanting/master_enchanter.mcfunction
# writing to enchanting/master_farmer.mcfunction
# writing to enchanting/master_fisher.mcfunction
# writing to enchanting/master_knight.mcfunction
# writing to enchanting/master_macerator.mcfunction
# writing to enchanting/master_miner.mcfunction
# writing to enchanting/master_sniper.mcfunction
# writing to enchanting/master_tridenteer.mcfunction
# writing to enchanting/needle_sharp.mcfunction
# writing to enchanting/newtons_flaming_laser_sword.mcfunction
# writing to enchanting/overkill.mcfunction
# writing to enchanting/over_overkill.mcfunction
# writing to enchanting/pick_like_silk.mcfunction
# writing to enchanting/root.mcfunction
# writing to enchanting/scuba_gear.mcfunction
# writing to enchanting/shotbow.mcfunction
# writing to enchanting/silent_but_deadly.mcfunction
# writing to enchanting/super_efficient.mcfunction
# writing to enchanting/this_name_sounds_cooler.mcfunction
# writing to enchanting/to_infinity_and_beyond.mcfunction
# writing to enchanting/unbreakable.mcfunction
# writing to enchanting/undead_slayer.mcfunction
# writing to enchanting/very_very_frightening.mcfunction
# writing to enchanting/whack_a_mole.mcfunction
# writing to enchanting/zeus.mcfunction
# writing to end/anti_gravity_generator.mcfunction
# writing to end/a_wizards_breakfast.mcfunction
# writing to end/cow_jumped_over_the_moon.mcfunction
# writing to end/dimension_penetration.mcfunction
# writing to end/divers_dozen.mcfunction
# writing to end/dogfight.mcfunction
# writing to end/dragon_shield.mcfunction
# writing to end/dragon_vs_dragon.mcfunction
# writing to end/end_bricks.mcfunction
# writing to end/event_horizon.mcfunction
# writing to end/extrabiologist.mcfunction
# writing to end/for_mother_clarence.mcfunction
# writing to end/free_the_end.mcfunction
# writing to end/getting_chorus.mcfunction
# writing to end/good_luck_getting_this_one.mcfunction
# writing to end/great_view_from_up_here.mcfunction
# writing to end/im_coming_back_murph.mcfunction
# writing to end/in_your_face_neil_armstrong.mcfunction
# writing to end/is_it_a_plane.mcfunction
# writing to end/no_dont_let_me_leave_murph.mcfunction
# writing to end/off_with_his_head.mcfunction
# writing to end/organizational_wizard.mcfunction
# writing to end/portable_storage.mcfunction
# writing to end/purpurfect.mcfunction
# writing to end/remote_getaway.mcfunction
# writing to end/ring_of_the_end.mcfunction
# writing to end/rocketman.mcfunction
# writing to end/root.mcfunction
# writing to end/shouldnt_my_shield_levitate_too.mcfunction
# writing to end/shulker_breaker.mcfunction
# writing to end/skys_the_limit.mcfunction
# writing to end/sky_high.mcfunction
# writing to end/somewhere_over_the_rainbow.mcfunction
# writing to end/some_breakthrough.mcfunction
# writing to end/the_actual_end.mcfunction
# writing to end/the_beginning.mcfunction
# writing to end/the_city_at_the_end_of_the_game.mcfunction
# writing to end/the_end_again.mcfunction
# writing to end/the_next_generation.mcfunction
# writing to end/the_point_of_no_return.mcfunction
# writing to end/the_start_of_something.mcfunction
# writing to end/the_void_frogs.mcfunction
# writing to end/uh_houston_we_have_a_problem.mcfunction
# writing to end/unending_hell.mcfunction
# writing to end/void_walker.mcfunction
# writing to end/what_for.mcfunction
# writing to farming/24_carrot_gold.mcfunction
# writing to farming/an_amazing_story.mcfunction
# writing to farming/an_apple_a_day.mcfunction
# writing to farming/aquatic_biofuel.mcfunction
# writing to farming/a_balanced_diet.mcfunction
# writing to farming/a_gluttonous_diet.mcfunction
# writing to farming/a_mangrove_grove.mcfunction
# writing to farming/a_seedy_place.mcfunction
# writing to farming/bake_bread.mcfunction
# writing to farming/bapple.mcfunction
# writing to farming/berry_nice.mcfunction
# writing to farming/care_for_the_environment.mcfunction
# writing to farming/castaway.mcfunction
# writing to farming/combine_harvester.mcfunction
# writing to farming/come_to_the_countryside.mcfunction
# writing to farming/die_potato.mcfunction
# writing to farming/disen_berry_berry_bad.mcfunction
# writing to farming/ecologist.mcfunction
# writing to farming/foliage.mcfunction
# writing to farming/full_stomach.mcfunction
# writing to farming/hay_there.mcfunction
# writing to farming/hot_chocolate.mcfunction
# writing to farming/im_gonna_be_sick.mcfunction
# writing to farming/its_a_cactus.mcfunction
# writing to farming/its_full_of_ink.mcfunction
# writing to farming/its_where_nutella_comes_from.mcfunction
# writing to farming/kelp_me.mcfunction
# writing to farming/meat_lovers.mcfunction
# writing to farming/mega_mushroom.mcfunction
# writing to farming/me_love_cookie.mcfunction
# writing to farming/mushroom_mushroom.mcfunction
# writing to farming/must_be_your_birthday.mcfunction
# writing to farming/naturally_carved.mcfunction
# writing to farming/natural_fertiliser.mcfunction
# writing to farming/not_today.mcfunction
# writing to farming/olaf.mcfunction
# writing to farming/one_course_meal.mcfunction
# writing to farming/pumpa_kungen.mcfunction
# writing to farming/root.mcfunction
# writing to farming/scientific_inaccuracy.mcfunction
# writing to farming/serious_dedication.mcfunction
# writing to farming/shrooms.mcfunction
# writing to farming/souperman.mcfunction
# writing to farming/spikey.mcfunction
# writing to farming/squid_game.mcfunction
# writing to farming/sugar_sugar.mcfunction
# writing to farming/suspicious_looking_stew.mcfunction
# writing to farming/the_garbage_will_do.mcfunction
# writing to farming/the_lie.mcfunction
# writing to farming/the_meloncholy_dane.mcfunction
# writing to farming/the_melon_the_melon_the_melon.mcfunction
# writing to farming/the_pie.mcfunction
# writing to farming/trimming_the_treetops.mcfunction
# writing to farming/ultra_hardcore.mcfunction
# writing to farming/undersea_gardener.mcfunction
# writing to farming/unmasked.mcfunction
# writing to farming/vegetarian.mcfunction
# writing to farming/whats_new_with_composting.mcfunction
# writing to farming/write_your_thoughts.mcfunction
# writing to farming/yay_deadbush.mcfunction
# writing to mining/9_to_5.mcfunction
# writing to mining/acquire_hardware.mcfunction
# writing to mining/amethyst_miner.mcfunction
# writing to mining/aww_it_broke.mcfunction
# writing to mining/a_shiny_treat.mcfunction
# writing to mining/blackout.mcfunction
# writing to mining/blind_as_a_bat.mcfunction
# writing to mining/bling_bling_gone.mcfunction
# writing to mining/bonfire_night.mcfunction
# writing to mining/bottom_to_top.mcfunction
# writing to mining/budget_channeling.mcfunction
# writing to mining/bulldozer.mcfunction
# writing to mining/called_shot.mcfunction
# writing to mining/caves_and_cliffs.mcfunction
# writing to mining/chestful_of_cobblestone.mcfunction
# writing to mining/coal_miner.mcfunction
# writing to mining/copper_miner.mcfunction
# writing to mining/cover_me_with_diamonds.mcfunction
# writing to mining/death_pointer.mcfunction
# writing to mining/deep_slate_nine.mcfunction
# writing to mining/diamonds.mcfunction
# writing to mining/diamonds_to_you.mcfunction
# writing to mining/diamond_clad.mcfunction
# writing to mining/diamond_miner.mcfunction
# writing to mining/diam_oh_wait_no.mcfunction
# writing to mining/dont_come_a_copper.mcfunction
# writing to mining/dripstone_drop.mcfunction
# writing to mining/dungeons_and_spawners.mcfunction
# writing to mining/echonomy.mcfunction
# writing to mining/eeuuwww.mcfunction
# writing to mining/emerald_miner.mcfunction
# writing to mining/enchanter.mcfunction
# writing to mining/even_moar_tools.mcfunction
# writing to mining/fallen_kingdom.mcfunction
# writing to mining/flint_miner.mcfunction
# writing to mining/fossil_fuel.mcfunction
# writing to mining/frigid_diversions.mcfunction
# writing to mining/galileo_figaro.mcfunction
# writing to mining/getting_an_upgrade.mcfunction
# writing to mining/gi_geode.mcfunction
# writing to mining/gold_mine.mcfunction
# writing to mining/gold_miner.mcfunction
# writing to mining/gold_rush.mcfunction
# writing to mining/good_for_your_bones.mcfunction
# writing to mining/grate_expectations.mcfunction
# writing to mining/heart_of_darkness.mcfunction
# writing to mining/hot_stuff.mcfunction
# writing to mining/hot_topic.mcfunction
# writing to mining/ice_bucket_challenge.mcfunction
# writing to mining/iconic_merchandising_prop.mcfunction
# writing to mining/iggy.mcfunction
# writing to mining/iron_man.mcfunction
# writing to mining/iron_miner.mcfunction
# writing to mining/isnt_it_iron_pick.mcfunction
# writing to mining/it_spreads.mcfunction
# writing to mining/lapis_lazuli_miner.mcfunction
# writing to mining/leaflet_drop.mcfunction
# writing to mining/lichen_subscribe.mcfunction
# writing to mining/living_like_kings.mcfunction
# writing to mining/lucky_break.mcfunction
# writing to mining/lush_hour.mcfunction
# writing to mining/master_coal_miner.mcfunction
# writing to mining/master_copper_miner.mcfunction
# writing to mining/master_diamond_miner.mcfunction
# writing to mining/master_gold_miner.mcfunction
# writing to mining/master_iron_miner.mcfunction
# writing to mining/meet_the_flintstones.mcfunction
# writing to mining/mineral_collection.mcfunction
# writing to mining/moar_broken_tools.mcfunction
# writing to mining/moar_tools.mcfunction
# writing to mining/moss_maker.mcfunction
# writing to mining/mr_bean.mcfunction
# writing to mining/my_work_here_is_done.mcfunction
# writing to mining/nananananananana.mcfunction
# writing to mining/not_chicken_mcnuggets.mcfunction
# writing to mining/obsidian_miner.mcfunction
# writing to mining/oresome.mcfunction
# writing to mining/particle_fan.mcfunction
# writing to mining/pixel_perfect.mcfunction
# writing to mining/redstone_miner.mcfunction
# writing to mining/renewable_energy.mcfunction
# writing to mining/rest_in_pickaxes.mcfunction
# writing to mining/rock_bottom.mcfunction
# writing to mining/root.mcfunction
# writing to mining/seeing_red.mcfunction
# writing to mining/shriek_forever_after.mcfunction
# writing to mining/sly_copper_the_copper_heist.mcfunction
# writing to mining/smokin_hot.mcfunction
# writing to mining/sneak_100.mcfunction
# writing to mining/spelunker.mcfunction
# writing to mining/stabcraft.mcfunction
# writing to mining/steals_on_wheels.mcfunction
# writing to mining/stone_age.mcfunction
# writing to mining/strike_a_light.mcfunction
# writing to mining/suit_up.mcfunction
# writing to mining/surge_protector.mcfunction
# writing to mining/thats_the_point.mcfunction
# writing to mining/the_mistake.mcfunction
# writing to mining/the_statue_of_liberty.mcfunction
# writing to mining/the_way_to_spawn.mcfunction
# writing to mining/this_dirt_is_dirtier.mcfunction
# writing to mining/this_is_mine_now.mcfunction
# writing to mining/wax_off.mcfunction
# writing to mining/wax_on.mcfunction
# writing to mining/weve_broken_our_last_shovel.mcfunction
# writing to mining/we_need_to_go_deeper.mcfunction
# writing to mining/whats_the_time_mr_wolf.mcfunction
# writing to mining/where_are_all_your_clothes.mcfunction
# writing to mining/youll_never_take_me_alive_copper.mcfunction
# writing to monsters/anti_air.mcfunction
# writing to monsters/aww_man.mcfunction
# writing to monsters/a_watery_grave.mcfunction
# writing to monsters/baby_baby_baby_noo.mcfunction
# writing to monsters/basketblock_championship.mcfunction
# writing to monsters/because_im_aquaman.mcfunction
# writing to monsters/blast_shield.mcfunction
# writing to monsters/blind_stare.mcfunction
# writing to monsters/bogged_down.mcfunction
# writing to monsters/boned.mcfunction
# writing to monsters/bone_to_party.mcfunction
# writing to monsters/camouflage.mcfunction
# writing to monsters/captain_etho.mcfunction
# writing to monsters/controlled_detonation.mcfunction
# writing to monsters/creeper_killer.mcfunction
# writing to monsters/creepy_heads.mcfunction
# writing to monsters/custom_boss_fight.mcfunction
# writing to monsters/dead_dont_die.mcfunction
# writing to monsters/dead_really_dont_die.mcfunction
# writing to monsters/desert_nomad.mcfunction
# writing to monsters/dungeon_crawler.mcfunction
# writing to monsters/enderman_destroyer.mcfunction
# writing to monsters/ender_worm.mcfunction
# writing to monsters/ew_ew_ew.mcfunction
# writing to monsters/family_reunion.mcfunction
# writing to monsters/freezing.mcfunction
# writing to monsters/frosty.mcfunction
# writing to monsters/gelatinous_cube.mcfunction
# writing to monsters/handsome_jack.mcfunction
# writing to monsters/hell_hunter.mcfunction
# writing to monsters/house_of_freaks.mcfunction
# writing to monsters/impossible.mcfunction
# writing to monsters/iron_belly.mcfunction
# writing to monsters/iskallium_collector.mcfunction
# writing to monsters/keep_your_distance.mcfunction
# writing to monsters/maximum_resistance.mcfunction
# writing to monsters/melting.mcfunction
# writing to monsters/miracle_drink.mcfunction
# writing to monsters/mollusc_man.mcfunction
# writing to monsters/monsters_hunted.mcfunction
# writing to monsters/monster_hunter.mcfunction
# writing to monsters/night_runner.mcfunction
# writing to monsters/not_afraid_of_heights.mcfunction
# writing to monsters/not_today_thank_you.mcfunction
# writing to monsters/now_thats_a_lot_of_damage.mcfunction
# writing to monsters/ooh_baby.mcfunction
# writing to monsters/paleontologist.mcfunction
# writing to monsters/phantom_slayer.mcfunction
# writing to monsters/plane_walker.mcfunction
# writing to monsters/poisonous_ew.mcfunction
# writing to monsters/poison_dart.mcfunction
# writing to monsters/poultry_boy.mcfunction
# writing to monsters/pupil_poppers.mcfunction
# writing to monsters/ricochet_swoop.mcfunction
# writing to monsters/root.mcfunction
# writing to monsters/skeleton_smiter.mcfunction
# writing to monsters/slime_squisher.mcfunction
# writing to monsters/spider_skeleton.mcfunction
# writing to monsters/spider_smasher.mcfunction
# writing to monsters/spooky_skeleton.mcfunction
# writing to monsters/spooky_skulls.mcfunction
# writing to monsters/stealth_is_optional.mcfunction
# writing to monsters/still_talking.mcfunction
# writing to monsters/taste_of_your_own_medicine.mcfunction
# writing to monsters/tele_morph.mcfunction
# writing to monsters/termite_control.mcfunction
# writing to monsters/there_has_to_be_another_way.mcfunction
# writing to monsters/the_ender_of_ender.mcfunction
# writing to monsters/the_ghastly_eyes.mcfunction
# writing to monsters/the_phantom_menace.mcfunction
# writing to monsters/the_undead_cavalry.mcfunction
# writing to monsters/trampoline.mcfunction
# writing to monsters/trick_or_treat.mcfunction
# writing to monsters/tridented_shield.mcfunction
# writing to monsters/two_birds_one_arrow.mcfunction
# writing to monsters/void_ender.mcfunction
# writing to monsters/warden_frostbite.mcfunction
# writing to monsters/well_handle_this.mcfunction
# writing to monsters/what_a_creep.mcfunction
# writing to monsters/witch.mcfunction
# writing to monsters/zombie_slayer.mcfunction
# writing to nether/anchorman.mcfunction
# writing to nether/ancient_restoration.mcfunction
# writing to nether/astrobrute.mcfunction
# writing to nether/a_knight_to_nether_forget.mcfunction
# writing to nether/a_piglins_best_friend.mcfunction
# writing to nether/a_soul_for_a_soul.mcfunction
# writing to nether/a_terrible_fortress.mcfunction
# writing to nether/basis_of_brewing.mcfunction
# writing to nether/beaconator.mcfunction
# writing to nether/beacon_overlord.mcfunction
# writing to nether/blaze_extinguisher.mcfunction
# writing to nether/bobbleheads.mcfunction
# writing to nether/bring_down_the_beast.mcfunction
# writing to nether/bring_home_the_beacon.mcfunction
# writing to nether/brute_force.mcfunction
# writing to nether/burnt_right_into_your_soul.mcfunction
# writing to nether/country_lode_take_me_home.mcfunction
# writing to nether/cultural_misunderstandings.mcfunction
# writing to nether/dark_ages.mcfunction
# writing to nether/decaying_beauty.mcfunction
# writing to nether/diamonds_are_not_forever.mcfunction
# writing to nether/dont_blink.mcfunction
# writing to nether/electrifying_alliance.mcfunction
# writing to nether/enders_chest.mcfunction
# writing to nether/et_tu_brute.mcfunction
# writing to nether/eye_spy.mcfunction
# writing to nether/feels_like_home.mcfunction
# writing to nether/fire_blast_shield.mcfunction
# writing to nether/fool_me_twice.mcfunction
# writing to nether/from_whence_it_came.mcfunction
# writing to nether/get_a_lode_of_this.mcfunction
# writing to nether/ghast_slayer.mcfunction
# writing to nether/giant_floating_jellyfish.mcfunction
# writing to nether/giddy_up.mcfunction
# writing to nether/gilded_miner.mcfunction
# writing to nether/gilty.mcfunction
# writing to nether/glowstone_miner.mcfunction
# writing to nether/glows_in_the_dark.mcfunction
# writing to nether/hells_bells.mcfunction
# writing to nether/hell_botanist.mcfunction
# writing to nether/high_temperature_fluid_monster.mcfunction
# writing to nether/holy_scrap.mcfunction
# writing to nether/hot_reels.mcfunction
# writing to nether/hot_spring.mcfunction
# writing to nether/hot_tourist_destination.mcfunction
# writing to nether/hung_drawn_and_bartered.mcfunction
# writing to nether/im_in_lava_with_you.mcfunction
# writing to nether/inception.mcfunction
# writing to nether/instant_mining.mcfunction
# writing to nether/into_fire.mcfunction
# writing to nether/is_it_a_balloon.mcfunction
# writing to nether/i_am_root.mcfunction
# writing to nether/jenga.mcfunction
# writing to nether/legend_of_hell_chicken_riders.mcfunction
# writing to nether/let_me_out.mcfunction
# writing to nether/limbo_walker.mcfunction
# writing to nether/local_brewery.mcfunction
# writing to nether/lodes_of_applications.mcfunction
# writing to nether/ludicrous_speed.mcfunction
# writing to nether/magma_cube_squisher.mcfunction
# writing to nether/master_netherite_miner.mcfunction
# writing to nether/moar_upgraded_tools.mcfunction
# writing to nether/netherite_mad_lad.mcfunction
# writing to nether/netherite_miner.mcfunction
# writing to nether/nether_rock_collection.mcfunction
# writing to nether/nether_say_die.mcfunction
# writing to nether/not_quite_nine_lives.mcfunction
# writing to nether/nugget_in_a_biscuit.mcfunction
# writing to nether/oh_shiny.mcfunction
# writing to nether/piglin_peril.mcfunction
# writing to nether/polar_opposites.mcfunction
# writing to nether/quicksand.mcfunction
# writing to nether/return_to_sender.mcfunction
# writing to nether/roadhog.mcfunction
# writing to nether/root.mcfunction
# writing to nether/seeing_stars.mcfunction
# writing to nether/soul_runnings.mcfunction
# writing to nether/spooky_scary_skeleton.mcfunction
# writing to nether/spreading_corruption.mcfunction
# writing to nether/stem_research.mcfunction
# writing to nether/stepping_on_legos.mcfunction
# writing to nether/subspace_bubble.mcfunction
# writing to nether/the_descent.mcfunction
# writing to nether/the_end.mcfunction
# writing to nether/the_hunt_begins.mcfunction
# writing to nether/the_nethers_shield.mcfunction
# writing to nether/the_struggle_nether_ends.mcfunction
# writing to nether/the_tribal_snouts.mcfunction
# writing to nether/this_boat_has_legs.mcfunction
# writing to nether/this_ones_mine.mcfunction
# writing to nether/those_were_the_days.mcfunction
# writing to nether/time_to_fire_back.mcfunction
# writing to nether/time_to_upgrade.mcfunction
# writing to nether/twisted.mcfunction
# writing to nether/uneasy_alliance.mcfunction
# writing to nether/war_pigs.mcfunction
# writing to nether/welcome_to_warp_zone.mcfunction
# writing to nether/we_got_a_live_one.mcfunction
# writing to nether/what_about_corruption_planks.mcfunction
# writing to nether/what_a_fungi.mcfunction
# writing to nether/when_hoglins_breed.mcfunction
# writing to nether/when_piglins_fly.mcfunction
# writing to nether/whole_hog.mcfunction
# writing to nether/who_is_cutting_onions.mcfunction
# writing to nether/withering_heights.mcfunction
# writing to nether/wub_wub_wub.mcfunction
# writing to nether/zork_chop.mcfunction
# writing to potion/a_furious_cocktail.mcfunction
# writing to potion/a_furious_test_subject.mcfunction
# writing to potion/a_much_more_doable_challenge.mcfunction
# writing to potion/a_weak_brew.mcfunction
# writing to potion/death_by_magic.mcfunction
# writing to potion/failed_concoctions.mcfunction
# writing to potion/final_shout.mcfunction
# writing to potion/furious_ammunition.mcfunction
# writing to potion/gas.mcfunction
# writing to potion/gas_bomb.mcfunction
# writing to potion/hopping_mad.mcfunction
# writing to potion/hyper_healing.mcfunction
# writing to potion/imbued_projectiles.mcfunction
# writing to potion/mad_scientist.mcfunction
# writing to potion/marine_marauder.mcfunction
# writing to potion/medic.mcfunction
# writing to potion/nocturnal.mcfunction
# writing to potion/noxious_fumes.mcfunction
# writing to potion/performance_enhancing_drugs.mcfunction
# writing to potion/root.mcfunction
# writing to potion/secret_of_the_ooze.mcfunction
# writing to potion/stayin_frosty.mcfunction
# writing to potion/stealth_takedown.mcfunction
# writing to potion/super_strength.mcfunction
# writing to potion/tank.mcfunction
# writing to potion/the_invisible_player.mcfunction
# writing to potion/true_feather_falling.mcfunction
# writing to potion/you_need_a_mint.mcfunction
# writing to potion/zombie_doctor.mcfunction
# writing to redstone/all_aboard.mcfunction
# writing to redstone/bling_plate.mcfunction
# writing to redstone/bullseye.mcfunction
# writing to redstone/calibration_sensation.mcfunction
# writing to redstone/cataclyst.mcfunction
# writing to redstone/click.mcfunction
# writing to redstone/comparing_comparator.mcfunction
# writing to redstone/craftception.mcfunction
# writing to redstone/crafters_crafting_crafters.mcfunction
# writing to redstone/dispense_with_this.mcfunction
# writing to redstone/electric_rails.mcfunction
# writing to redstone/engineer.mcfunction
# writing to redstone/factorio.mcfunction
# writing to redstone/fuel_engine.mcfunction
# writing to redstone/leveraging_synergy.mcfunction
# writing to redstone/master_engineer.mcfunction
# writing to redstone/metal_plate.mcfunction
# writing to redstone/mobile_explosion.mcfunction
# writing to redstone/monstrous_music.mcfunction
# writing to redstone/monstrous_sacrifices.mcfunction
# writing to redstone/moving_moving_storage.mcfunction
# writing to redstone/moving_parts.mcfunction
# writing to redstone/moving_storage.mcfunction
# writing to redstone/mozart.mcfunction
# writing to redstone/noteworthy.mcfunction
# writing to redstone/observer_buddy.mcfunction
# writing to redstone/on_a_rail.mcfunction
# writing to redstone/powerful_light.mcfunction
# writing to redstone/pressure_detector.mcfunction
# writing to redstone/quartz_miner.mcfunction
# writing to redstone/quirky_quartz.mcfunction
# writing to redstone/railwayman.mcfunction
# writing to redstone/repeating_repeater.mcfunction
# writing to redstone/root.mcfunction
# writing to redstone/sculker_box.mcfunction
# writing to redstone/solar_power.mcfunction
# writing to redstone/space_dropper.mcfunction
# writing to redstone/space_hopper.mcfunction
# writing to redstone/sticky_parts.mcfunction
# writing to redstone/take_notes.mcfunction
# writing to redstone/target_acquired.mcfunction
# writing to redstone/target_practise.mcfunction
# writing to redstone/the_block_of_eternal_screaming.mcfunction
# writing to redstone/the_incredible_sculk.mcfunction
# writing to redstone/the_power_of_books.mcfunction
# writing to redstone/travelling_bard.mcfunction
# writing to redstone/tripping_over.mcfunction
# writing to redstone/troll_chest.mcfunction
# writing to redstone/under_pressure.mcfunction
# writing to redstone/vibe_check.mcfunction
# writing to redstone/we_have_liftoff.mcfunction
# writing to statistics/65_hours_of_walking.mcfunction
# writing to statistics/ancient_kung_fu_master.mcfunction
# writing to statistics/big_spender.mcfunction
# writing to statistics/black_belt_ninja.mcfunction
# writing to statistics/bloodthirsty.mcfunction
# writing to statistics/boing_boing.mcfunction
# writing to statistics/cupid.mcfunction
# writing to statistics/elderly_enchanter.mcfunction
# writing to statistics/food_glorious_food.mcfunction
# writing to statistics/frequent_flyer.mcfunction
# writing to statistics/giga_xp_grinder.mcfunction
# writing to statistics/global_railway_network.mcfunction
# writing to statistics/happy_new_year.mcfunction
# writing to statistics/horse_training.mcfunction
# writing to statistics/i_enjoy_long_walks_and_playing_minecraft.mcfunction
# writing to statistics/i_heart_chests.mcfunction
# writing to statistics/i_like_trains.mcfunction
# writing to statistics/journeyman_enchanter.mcfunction
# writing to statistics/jumping_jacks.mcfunction
# writing to statistics/kill_or_be_killed.mcfunction
# writing to statistics/laps_in_the_pool.mcfunction
# writing to statistics/level_up.mcfunction
# writing to statistics/lightning_mcpig.mcfunction
# writing to statistics/loot_em.mcfunction
# writing to statistics/luxury_cruise.mcfunction
# writing to statistics/marathon.mcfunction
# writing to statistics/minecart_rider.mcfunction
# writing to statistics/mob_hunter.mcfunction
# writing to statistics/more_for_me.mcfunction
# writing to statistics/natural_sprinter.mcfunction
# writing to statistics/novice_enchanter.mcfunction
# writing to statistics/olympic_athlete.mcfunction
# writing to statistics/olympic_gold_medallist.mcfunction
# writing to statistics/om_nom_nom.mcfunction
# writing to statistics/out_for_a_stroll.mcfunction
# writing to statistics/overlevelling.mcfunction
# writing to statistics/passing_the_time.mcfunction
# writing to statistics/pig_training.mcfunction
# writing to statistics/pirate_captain.mcfunction
# writing to statistics/root.mcfunction
# writing to statistics/sailor_of_the_seven_seas.mcfunction
# writing to statistics/scourge_of_the_west.mcfunction
# writing to statistics/sheriff_firearm.mcfunction
# writing to statistics/sneaky_snitch.mcfunction
# writing to statistics/snout_500.mcfunction
# writing to statistics/spring_in_your_step.mcfunction
# writing to statistics/stonks.mcfunction
# writing to statistics/supersonic.mcfunction
# writing to statistics/take_to_the_skies.mcfunction
# writing to statistics/taking_it_in_stride.mcfunction
# writing to statistics/the_first_night.mcfunction
# writing to statistics/the_haggler.mcfunction
# writing to statistics/the_parrots_and_the_bats.mcfunction
# writing to statistics/this_ride_is_lit_yo.mcfunction
# writing to statistics/two_by_two.mcfunction
# writing to statistics/who_needs_boats.mcfunction
# writing to statistics/who_needs_cars.mcfunction
# writing to statistics/xp_grinder.mcfunction
# writing to statistics/your_legs_must_be_tired.mcfunction
# writing to statistics/yum_yum_yummo.mcfunction
# writing to weaponry/artillery.mcfunction
# writing to weaponry/axeman.mcfunction
# writing to weaponry/a_snowballs_chance_in_hell.mcfunction
# writing to weaponry/a_throwaway_joke.mcfunction
# writing to weaponry/backfire.mcfunction
# writing to weaponry/bombs_away.mcfunction
# writing to weaponry/bow_spammer.mcfunction
# writing to weaponry/demolitions_expert.mcfunction
# writing to weaponry/diemonds.mcfunction
# writing to weaponry/egging_dude.mcfunction
# writing to weaponry/expelliarmus.mcfunction
# writing to weaponry/explosive_fire.mcfunction
# writing to weaponry/fireworks_display.mcfunction
# writing to weaponry/flying_colors.mcfunction
# writing to weaponry/half_heart_life.mcfunction
# writing to weaponry/indiana_jones.mcfunction
# writing to weaponry/inspector_gadget.mcfunction
# writing to weaponry/its_time_consuming.mcfunction
# writing to weaponry/king_of_the_sea.mcfunction
# writing to weaponry/loser.mcfunction
# writing to weaponry/master_shieldsman.mcfunction
# writing to weaponry/meteor_strike.mcfunction
# writing to weaponry/multiclassed.mcfunction
# writing to weaponry/my_eyes.mcfunction
# writing to weaponry/nice_to_mace_you.mcfunction
# writing to weaponry/ol_betsy.mcfunction
# writing to weaponry/pig_fishing_tournament.mcfunction
# writing to weaponry/point_blank.mcfunction
# writing to weaponry/poseidon_vs_hades.mcfunction
# writing to weaponry/pyrotechnic.mcfunction
# writing to weaponry/revenge.mcfunction
# writing to weaponry/rock_paper_shears.mcfunction
# writing to weaponry/root.mcfunction
# writing to weaponry/shield_luck.mcfunction
# writing to weaponry/shovel_knight.mcfunction
# writing to weaponry/sir_knight.mcfunction
# writing to weaponry/slapfish.mcfunction
# writing to weaponry/sniper_duel.mcfunction
# writing to weaponry/snowball_fight.mcfunction
# writing to weaponry/spleaf.mcfunction
# writing to weaponry/take_aim.mcfunction
# writing to weaponry/that_is_so_fletch.mcfunction
# writing to weaponry/theres_yolk_on_my_head.mcfunction
# writing to weaponry/there_it_goes.mcfunction
# writing to weaponry/the_aquatic_hunter.mcfunction
# writing to weaponry/the_mighty_hunter.mcfunction
# writing to weaponry/viking.mcfunction
# writing to weaponry/warden_extinction.mcfunction
# writing to weaponry/when_pigs_finally_fly.mcfunction
# writing to weaponry/whos_the_pillager_now.mcfunction
# writing to weaponry/who_ya_gonna_call.mcfunction
# writing to weaponry/x_bow.mcfunction
